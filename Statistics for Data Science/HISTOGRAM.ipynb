# %%
import matplotlib.pyplot as plt
data=[45,50,52,55,60,65,70,72,75,80,85]

plt.hist(data, bins=5)
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.title("Hitogram")
plt.show()

# %% [markdown]
# data = [45, 50, 52, 55, 60, 62, 65, 70, 72, 75, 80, 85]
# bins = 5
# Minimum (min) = 45
# Maximum (max) = 85
#
# Range = max-min = 85-45 = 40
#
#
# Bin width = Range/Number of bins
#           =40/5
#           = 8
#
# | Bin | Interval |
# | --- | -------- |
# | 1   | 45-53    |
# | 2   | 53-61    |
# | 3   | 61- 69   |
# | 4   | 69 - 77  |
# | 5   | 77 - 85  |
#
#
# | Bin Range | Values     | Frequency |
# | --------- | ---------- | --------- |
# | 45–53     | 45, 50, 52 | 3         |
# | 53–61     | 55, 60     | 2         |
# | 61–69     | 62, 65     | 2         |
# | 69–77     | 70, 72, 75 | 3         |
# | 77–85     | 80, 85     | 2         |
#
#
# Frequencies: [3 2 2 3 2]
# Bin edges: [45. 53. 61. 69. 77. 85.]
