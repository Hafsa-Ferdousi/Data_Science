# %%
import numpy as np

# Generate 1000 values with mean=0, std=1
data = np.random.normal(loc=0, scale=1, size=1000)

print(data[:10])
# Out:
# [ 0.8760982  -1.86410318  0.24450736 -1.25399713  1.67764746  0.7391468
#  -1.24334477 -0.3830516   1.57959294  2.13961481]

# %% [markdown]
# loc → mean (μ)
#
# scale → standard deviation (σ)
#
# size → number of samples

# %%
print(data[:30])
# Out:
# [ 0.8760982  -1.86410318  0.24450736 -1.25399713  1.67764746  0.7391468
#  -1.24334477 -0.3830516   1.57959294  2.13961481  0.05421577  0.86820226
#   1.82147476  0.87869344 -0.87565455  0.05698013 -0.11225919 -0.17917059
#  -0.67043047 -1.52883309 -1.21524511  1.49641013  1.20736003  2.76251196
#  -1.32374669 -0.56820379  1.19225243  0.32499574 -1.92462754 -0.66574944]

# %% [markdown]
# **Plot Histogram**

# %%
import matplotlib.pyplot as plt

plt.hist(data, bins=30, density=True)
plt.title("Normal Distribution")
plt.xlabel("Value")
plt.ylabel("Probability")
plt.show()

# %%
from scipy.stats import norm
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-4, 4, 100)

# mean=0, std=1
pdf = norm.pdf(x, loc=0, scale=1)

plt.plot(x, pdf)
plt.title("Normal Distribution PDF")
plt.show()
