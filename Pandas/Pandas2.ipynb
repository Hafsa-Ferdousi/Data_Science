# %%
import numpy as np
import pandas as pd

dict={
    "Name":['Simi', 'Hafsa', 'Nafisa', 'Sadia'],
    "Mark":[90, 82, 85, 89],
    "City":['Rampura','Alamdanga','Comilla','Puran Dhaka']

}

# %%
df=pd.DataFrame(dict)

# %%
df
# Out:
#      Name  Mark         City
# 0    Simi    90      Rampura
# 1   Hafsa    82    Alamdanga
# 2  Nafisa    85      Comilla
# 3   Sadia    89  Puran Dhaka

# %%
df.to_csv('friend.csv')

# %%
df.to_csv('friends.csv', index=False)

# %%
df.head(2)
# Out:
#     Name  Mark       City
# 0   Simi    90    Rampura
# 1  Hafsa    82  Alamdanga

# %%
df.tail(2)
# Out:
#      Name  Mark         City
# 2  Nafisa    85      Comilla
# 3   Sadia    89  Puran Dhaka

# %%
df.describe()
# Out:
#             Mark
# count   4.000000
# mean   86.500000
# std     3.696846
# min    82.000000
# 25%    84.250000
# 50%    87.000000
# 75%    89.250000
# max    90.000000

# %%
df["Name"]
# Out:
# 0      Simi
# 1     Hafsa
# 2    Nafisa
# 3     Sadia
# Name: Name, dtype: object

# %%
df[["Name", "Mark"]]
# Out:
#      Name  Mark
# 0    Simi    90
# 1   Hafsa    82
# 2  Nafisa    85
# 3   Sadia    89

# %%
df.loc[0]
# Out:
# Name       Simi
# Mark         90
# City    Rampura
# Name: 0, dtype: object

# %%
df.iloc[1]
# Out:
# Name        Hafsa
# Mark           82
# City    Alamdanga
# Name: 1, dtype: object

# %%
df[df["Mark"]>85]
# Out:
#     Name  Mark         City
# 0   Simi    90      Rampura
# 3  Sadia    89  Puran Dhaka

# %%
df[df["Mark"] > 85]["Name"]
# Out:
# 0     Simi
# 3    Sadia
# Name: Name, dtype: object

# %%
df["Pet"]=["No","NOOO","NOO","Cat"]

# %%
df
# Out:
#      Name  Mark         City   Pet
# 0    Simi    90      Rampura    No
# 1   Hafsa    82    Alamdanga  NOOO
# 2  Nafisa    85      Comilla   NOO
# 3   Sadia    89  Puran Dhaka   Cat

# %%
df["Mark"].mean()
# Out:
# np.float64(86.5)

# %%
df.sort_values("Mark")
# Out:
#      Name  Mark         City   Pet
# 1   Hafsa    82    Alamdanga  NOOO
# 2  Nafisa    85      Comilla   NOO
# 3   Sadia    89  Puran Dhaka   Cat
# 0    Simi    90      Rampura    No

# %%
df["City"].unique()
# Out:
# array(['Rampura', 'Alamdanga', 'Comilla', 'Puran Dhaka'], dtype=object)

# %%
df[df["Mark"]==df["Mark"].max()]
# Out:
#    Name  Mark     City Pet
# 0  Simi    90  Rampura  No

# %%
df[df['Mark']==df['Mark'].min()]
# Out:
#     Name  Mark       City   Pet
# 1  Hafsa    82  Alamdanga  NOOO

# %%
df.nlargest(2,'Mark')
# Out:
#     Name  Mark         City  Pet
# 0   Simi    90      Rampura   No
# 3  Sadia    89  Puran Dhaka  Cat
