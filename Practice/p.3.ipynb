# %%
import json,pandas as pd
from pathlib import Path
from dateutil import parser as dateparser
pd.set_option('display.max_columns',50)
pd.set_option('display.max_rows',120)

df=pd.read_json("C:\\Users\\Asus\\Downloads\\used_cars_train.json",lines=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 71275 entries, 0 to 71274
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            71275 non-null  int64
#  1   price         71275 non-null  int64
#  2   year          71275 non-null  int64
#  3   manufacturer  71275 non-null  str
#  4   model         71275 non-null  str
#  5   condition     71275 non-null  str
#  6   cylinders     71275 non-null  str
#  7   fuel          71275 non-null  str
#  8   odometer      71275 non-null  int64
#  9   title_status  71275 non-null  str
#  10  transmission  71275 non-null  str
#  11  drive         71275 non-null  str
#  12  size          71275 non-null  str
#  13  type          71275 non-null  str
#  14  paint_color   71275 non-null  str
#  15  state         71275 non-null  str
#  16  posting_date  71275 non-null  str
# dtypes: int64(4), str(13)
# memory usage: 9.2 MB

# %%
df.head(9)
# Out:
#            id  price  year manufacturer                       model  \
# 0  7314977535   4000  2007         jeep      grand cherokee limited
# 1  7314789720   4800  2006    chevrolet                   silverado
# 2  7304863686   5500  2007       toyota                       yaris
# 3  7311469964  26990  2016    chevrolet  express commercial cutaway
# 4  7305988194  48995  2020       toyota          tundra limited 4x4
# 5  7315190187   1850  2002   volkswagen                   jetta gls
# 6  7306600292   5450  2008       toyota                       prius
# 7  7310463988      0  2018       nissan                    frontier
# 8  7311284369   7000  2002          ram               2500 quad cab
#
#    condition     cylinders fuel  odometer title_status transmission drive  \
# 0       good   8 cylinders  gas    278000        clean    automatic   4wd
# 1       good   8 cylinders  gas    260600        clean    automatic   rwd
# 2  excellent   4 cylinders  gas     51000        clean       manual   fwd
# 3       good   8 cylinders  gas     75734        clean    automatic   rwd
# 4   like new   8 cylinders  gas     20000         lien    automatic   4wd
# 5       good   4 cylinders  gas    240000        clean       manual   fwd
# 6       good   4 cylinders  gas    174576        clean    automatic   fwd
# 7  excellent   6 cylinders  gas     75579        clean    automatic   4wd
# 8  excellent  10 cylinders  gas    137951        clean    automatic   4wd
#
#         size       type paint_color state              posting_date
# 0   mid-size        SUV      silver    or  2021-04-30T12:43:00-0700
# 1  full-size     pickup       white    fl  2021-04-30T10:31:34-0400
# 2    compact  hatchback        blue    al  2021-04-10T15:11:21-0500
# 3  full-size      truck       white    wi  2021-04-23T13:13:09-0500
# 4  full-size      truck      silver    nm  2021-04-12T20:01:35-0600
# 5   mid-size      sedan       black    ca  2021-04-30T23:01:08-0700
# 6    compact  hatchback      silver    mo  2021-04-14T07:54:47-0500
# 7    compact      truck        blue    ok  2021-04-21T13:36:23-0500
# 8  full-size      truck        blue    ny  2021-04-23T09:06:19-0400

# %%
df.isna().mean().sort_values(ascending=False).head(20)
# Out:
# id              0.0
# price           0.0
# year            0.0
# manufacturer    0.0
# model           0.0
# condition       0.0
# cylinders       0.0
# fuel            0.0
# odometer        0.0
# title_status    0.0
# transmission    0.0
# drive           0.0
# size            0.0
# type            0.0
# paint_color     0.0
# state           0.0
# posting_date    0.0
# dtype: float64

# %%
categorical_cols=["manufacturer","model","fuel","transmission"]
