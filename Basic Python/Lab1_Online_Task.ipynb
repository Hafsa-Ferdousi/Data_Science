# %% [markdown]
# # Lab 1 — Online Task
# **Instructions:** Fill in the `# YOUR CODE HERE` sections. Do not change function names or test cells.
# Run **Kernel → Restart & Run All** before submission; all checks should pass.
#
# **Time:** 20 minutes.

# %%
# Task: Implement letter_grade(mark) based on the scale:
# A: >=80, B: >=70, C: >=60, D: >=50, F: otherwise

def letter_grade(mark):
    # YOUR CODE HERE

# DO NOT MODIFY BELOW
for m, g in [(85,"A"), (79,"B"), (60,"C"), (55,"D"), (41,"F")]:
    assert letter_grade(m) == g
print("✓ If/Else: OK")
# Out:
#   Cell In[1], line 8
#     for m, g in [(85,"A"), (79,"B"), (60,"C"), (55,"D"), (41,"F")]:
#     ^
# IndentationError: expected an indented block after function definition on line 4
